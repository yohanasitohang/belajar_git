# %%
print ("nama saya yohana")
# Out:
# nama saya yohana

# %%
print('cell code ini adalah berisi kode untuk pie charts')
# Out:
# cell code ini adalah berisi kode untuk pie charts

# %% [markdown]
# disini baru bisa tulis insight nya dari hasil

# %% [markdown]
# ## ini adalah judul **bold**

# %% [markdown]
# ini adalah tulisan *italic*

# %% [markdown]
# ### ini adalah kode untuk melihat versi python yang sedang digunakan
# import sys
# sys.version
